# %%
import pandas as pd

# %%
data = pd.read_csv("/home/ecapi/code/e-capi/website_water_pollution/croquis_coord/PolygonConverted.csv", encoding_errors="ignore")
# Out:
# /home/ecapi/.pyenv/versions/3.8.12/envs/website_water_pollution/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5,7,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#         PolygonID dissolve  scalerank featurecla             name name_alt  \
# 0               1   0River          1      River  Irrawaddy Delta      NaN
# 1               1   0River          1      River  Irrawaddy Delta      NaN
# 2               1   0River          1      River  Irrawaddy Delta      NaN
# 3               1   0River          1      River  Irrawaddy Delta      NaN
# 4               1   0River          1      River  Irrawaddy Delta      NaN
# ...           ...      ...        ...        ...              ...      ...
# 256380       1455  303Drau          7      River             Drau    Drava
# 256381       1455  303Drau          7      River             Drau    Drava
# 256382       1455  303Drau          7      River             Drau    Drava
# 256383       1455  303Drau          7      River             Drau    Drava
# 256384       1455  303Drau          7      River             Drau    Drava
#
# ...

# %%
df = data[["name", "PointID", "Longitude", "Latitude"]]

# %%
#extract the coordinates of the river we want to analyse
df[df["name"] == "Sane"]
# Out:
#         name  PointID  Longitude   Latitude
# 246829  Sane        1   4.951101  46.833360
# 246830  Sane        2   4.934255  46.820909
# 246831  Sane        3   4.917410  46.811794
# 246832  Sane        4   4.908458  46.808173
# 246833  Sane        5   4.881114  46.806260
# ...      ...      ...        ...        ...
# 246888  Sane       60   4.840017  45.799994
# 246889  Sane       61   4.838064  45.789008
# 246890  Sane       62   4.837413  45.777167
# 246891  Sane       63   4.836111  45.768581
# 246892  Sane       64   4.830577  45.751532
#
# [64 rows x 4 columns]

# %% [markdown]
# ## Add a color column for the plot

# %%
df_Saone = df[df["name"] == "Sane"].copy()

# %%
# df_Saone["color"] = "#ffe800"

# %%
df_Saone
# Out:
#         name  PointID  Longitude   Latitude
# 246829  Sane        1   4.951101  46.833360
# 246830  Sane        2   4.934255  46.820909
# 246831  Sane        3   4.917410  46.811794
# 246832  Sane        4   4.908458  46.808173
# 246833  Sane        5   4.881114  46.806260
# ...      ...      ...        ...        ...
# 246888  Sane       60   4.840017  45.799994
# 246889  Sane       61   4.838064  45.789008
# 246890  Sane       62   4.837413  45.777167
# 246891  Sane       63   4.836111  45.768581
# 246892  Sane       64   4.830577  45.751532
#
# [64 rows x 4 columns]

# %%
lat_list = df_Saone.Latitude.to_list()
long_list = df_Saone.Longitude.to_list()

# %%
#list of coordinates for one river
coord_list = zip(lat_list, long_list)

# nl = [f"{lat}, {long}" for lat, long in zip(lat_list, long_list)] #if no need of tupple
#nl
coord_list = list(coord_list)

# %%
coord_list
# Out:
# [(46.8333600932232, 4.95110110768792),
#  (46.8209089213482, 4.93425540456292),
#  (46.8117943380149, 4.91740970143792),
#  (46.808172918744, 4.90845787852126),
#  (46.8062604838482, 4.88111412852126),
#  (46.8036563171815, 4.87671959727126),
#  (46.7966576192649, 4.87354576914626),
#  (46.7830671244732, 4.86182701914626),
#  (46.7711856140565, 4.86573326914626),
#  (46.7539330098899, 4.88502037852126),
#  (46.7383080098899, 4.90813235768792),
#  (46.724188543744, 4.94459069102126),
#  (46.705633856244, 4.95915774831292),
#  (46.6810163432232, 4.96705162852126),
#  (46.655829168744, 4.96827233164626),
#  (46.6309675150982, 4.96404056081292),
#  (46.6039492859315, 4.95606530039626),
#  (46.578924871869, 4.94556725352126),
#  (46.5602481140565, 4.93425540456292),
#  (46.5422630880149, 4.93962649831292),
#  (46.516913153119, 4.94231204518792),
#  (46.4943301453065, 4.93995201914626),
#  (46.4751244161399, 4.92033938893792),
#  (46.4094505880149, 4.90626061289626),
# ...

# %%
df_map = pd.DataFrame.from_dict({"name": ["Saone"], "Color": ["ffe800"], "Coord": [coord_list]})
df_map
# Out:
#     name   Color                                              Coord
# 0  Saone  ffe800  [(46.8333600932232, 4.95110110768792), (46.820...

# %%
# make a list per coordinate
def list_of_coord(coord_list = coord_list):
    
    list_of_lists_coord = []
    for coord in coord_list:
        list_of_lists_coord.append([coord])
        
    return list_of_lists_coord
list_of_list_coord = list_of_coord()

# %%
list_of_list_coord
# Out:
# [[(46.8333600932232, 4.95110110768792)],
#  [(46.8209089213482, 4.93425540456292)],
#  [(46.8117943380149, 4.91740970143792)],
#  [(46.808172918744, 4.90845787852126)],
#  [(46.8062604838482, 4.88111412852126)],
#  [(46.8036563171815, 4.87671959727126)],
#  [(46.7966576192649, 4.87354576914626)],
#  [(46.7830671244732, 4.86182701914626)],
#  [(46.7711856140565, 4.86573326914626)],
#  [(46.7539330098899, 4.88502037852126)],
#  [(46.7383080098899, 4.90813235768792)],
#  [(46.724188543744, 4.94459069102126)],
#  [(46.705633856244, 4.95915774831292)],
#  [(46.6810163432232, 4.96705162852126)],
#  [(46.655829168744, 4.96827233164626)],
#  [(46.6309675150982, 4.96404056081292)],
#  [(46.6039492859315, 4.95606530039626)],
#  [(46.578924871869, 4.94556725352126)],
#  [(46.5602481140565, 4.93425540456292)],
#  [(46.5422630880149, 4.93962649831292)],
#  [(46.516913153119, 4.94231204518792)],
#  [(46.4943301453065, 4.93995201914626)],
#  [(46.4751244161399, 4.92033938893792)],
# ...

# %%
pd.DataFrame.from_dict({"name": ["Saone"], "Color": ["ffe800"], "Coord": [list_of_list_coord]})
# Out:
#     name   Color                                              Coord
# 0  Saone  ffe800  [[(46.8333600932232, 4.95110110768792)], [(46....

# %%
river_df = pd.DataFrame(columns=["name", "color", "coord"])
river_df.iloc[0] = ["Saone", "#ffe800", list_of_coord]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_23375/3155852375.py in <module>
#       1 river_df = pd.DataFrame(columns=["name", "color", "coord"])
# ----> 2 river_df.iloc[0] = ["Saone", "#ffe800", list_of_coord]
#
# ~/.pyenv/versions/3.8.12/envs/website_water_pollution/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     718             key = com.apply_if_callable(key, self.obj)
#     719         indexer = self._get_setitem_indexer(key)
# --> 720         self._has_valid_setitem_indexer(key)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
#
# ~/.pyenv/versions/3.8.12/envs/website_water_pollution/lib/python3.8/site-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1459             elif is_integer(i):
#    1460                 if i >= len(ax):
# ...

# %%
river_df
# Out:
# Empty DataFrame
# Columns: [name, color, coord]
# Index: []

# %%
df_examp = df_Saone.iloc[:1]

# %%
df_examp.drop(columns=['name', "PointID"],inplace=True)
# Out:
# /home/ecapi/.pyenv/versions/3.8.12/envs/website_water_pollution/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_examp
# Out:
#         Longitude  Latitude
# 246829   4.951101  46.83336

# %%
df_examp["color"] = "#ffe800"
# Out:
# /tmp/ipykernel_23375/3600609582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_examp["color"] = "#ffe800"

# %%
df_examp
# Out:
#         Longitude  Latitude    color
# 246829   4.951101  46.83336  #ffe800

# %%
long_list = df_examp.Longitude.to_list()

# %%
long_list
# Out:
# [4.95110110768792]
